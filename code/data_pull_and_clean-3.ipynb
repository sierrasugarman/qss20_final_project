# %%
import pandas as pd

# %%
violence_data = pd.read_excel("../data/Violence Data.xlsx")

# %%
state_religion_data = pd.read_excel("../data/state_religions.xlsx")

# %%
print(violence_data.head())
violence_data.shape
# Out:
#    country_id_cy   country_cy  year_cy region_cy          main_govt_name_cy  \
# 0            700  Afghanistan     1989      Asia  Government of Afghanistan
# 1            700  Afghanistan     1990      Asia  Government of Afghanistan
# 2            700  Afghanistan     1991      Asia  Government of Afghanistan
# 3            700  Afghanistan     1992      Asia  Government of Afghanistan
# 4            700  Afghanistan     1993      Asia  Government of Afghanistan
#
#    sb_exist_cy  sb_dyad_count_cy           sb_dyad_ids_cy  \
# 0            1                 5  724; 726; 727; 729; 732
# 1            1                 5  724; 726; 727; 732; 733
# 2            1                 4       724; 726; 727; 732
# 3            1                 4       724; 726; 727; 732
# 4            1                 4       726; 732; 734; 842
#
#                                     sb_dyad_names_cy  sb_deaths_parties_cy  \
# 0  Government of Afghanistan - Hizb-i Islami-yi A...                  1019
# 1  Government of Afghanistan - Hizb-i Islami-yi A...                   704
# 2  Government of Afghanistan - Hizb-i Islami-yi A...                  2274
# 3  Government of Afghanistan - Hizb-i Islami-yi A...                   187
# 4  Government of Afghanistan - Hizb-i Islami-yi A...                   554
#
#    ...  os_total_deaths_best_cy  os_total_deaths_high_cy  \
# 0  ...                        0                        0
# 1  ...                        0                        0
# 2  ...                        0                        0
# 3  ...                        8                      304
# 4  ...                       26                      240
#
#    os_total_deaths_low_cy  cumulative_total_deaths_parties_in_orgvio_cy  \
# 0                       0                                          1065
# 1                       0                                           724
# 2                       0                                          2274
# 3                       8                                           187
# 4                      26                                           556
#
#    cumulative_total_deaths_civilians_in_orgvio_cy  \
# 0                                             303
# 1                                             101
# 2                                              49
# 3                                            1695
# 4                                             637
#
#    cumulative_total_deaths_unknown_in_orgvio_cy  \
# 0                                          4043
# 1                                           689
# 2                                          1230
# 3                                          2503
# 4                                          2912
#
#    cumulative_total_deaths_in_orgvio_best_cy  \
# 0                                       5411
# 1                                       1514
# 2                                       3553
# 3                                       4385
# 4                                       4105
#
#   cumulative_total_deaths_in_orgvio_high_cy  \
# 0                                     17642
# 1                                      2311
# 2                                      4053
# 3                                      5865
# 4                                      8433
#
#   cumulative_total_deaths_in_orgvio_low_cy  version
# 0                                     2141     25.1
# 1                                     1359     25.1
# 2                                     3407     25.1
# 3                                     4368     25.1
# 4                                     4097     25.1
#
# [5 rows x 74 columns]
# (6936, 74)

# %%
violence_data2 = violence_data[violence_data["sb_intrastate_exist_cy"] == 1]

violence_filtered = violence_data2[[
    "country_cy",
    "year_cy",
    "sb_intrastate_deaths_best_cy",
    "sb_intrastate_deaths_civilians_cy"
]]
violence_filtered.head()
# Out:
#     country_cy  year_cy  sb_intrastate_deaths_best_cy  \
# 0  Afghanistan     1989                          5174
# 1  Afghanistan     1990                          1478
# 2  Afghanistan     1991                          3302
# 3  Afghanistan     1992                          4287
# 4  Afghanistan     1993                          4071
#
#    sb_intrastate_deaths_civilians_cy
# 0                                303
# 1                                101
# 2                                 38
# 3                               1687
# 4                                611

# %%
violence_filtered = violence_filtered.rename(columns={
    "country_cy": "country",
    "year_cy": "year",
    "sb_intrastate_deaths_best_cy": "intrastate_deaths",
    "sb_intrastate_deaths_civilians_cy": "civilian_deaths"
})
violence_filtered.head()
# Out:
#        country  year  intrastate_deaths  civilian_deaths
# 0  Afghanistan  1989               5174              303
# 1  Afghanistan  1990               1478              101
# 2  Afghanistan  1991               3302               38
# 3  Afghanistan  1992               4287             1687
# 4  Afghanistan  1993               4071              611

# %%
print(state_religion_data.head())
state_religion_data.shape
print(state_religion_data.columns)
# Out:
#    Unnamed: 0  ccode        cname  year  ccode_qog    cname_qog ccodealp  \
# 0          46    4.0  Afghanistan  1992          4  Afghanistan      AFG
# 1          47    4.0  Afghanistan  1993          4  Afghanistan      AFG
# 2          48    4.0  Afghanistan  1994          4  Afghanistan      AFG
# 3          49    4.0  Afghanistan  1995          4  Afghanistan      AFG
# 4          50    4.0  Afghanistan  1996          4  Afghanistan      AFG
#
#    ccodecow        cname_year ccodealp_year  biu_offrel
# 0     700.0  Afghanistan 1992         AFG92           2
# 1     700.0  Afghanistan 1993         AFG93           2
# 2     700.0  Afghanistan 1994         AFG94           2
# 3     700.0  Afghanistan 1995         AFG95           2
# 4     700.0  Afghanistan 1996         AFG96           2
# Index(['Unnamed: 0', 'ccode', 'cname', 'year', 'ccode_qog', 'cname_qog',
#        'ccodealp', 'ccodecow', 'cname_year', 'ccodealp_year', 'biu_offrel'],
#       dtype='object')

# %%
religion_filtered = state_religion_data[[
    "cname",
    "biu_offrel"
]]
religion_filtered.head()
# Out:
#          cname  biu_offrel
# 0  Afghanistan           2
# 1  Afghanistan           2
# 2  Afghanistan           2
# 3  Afghanistan           2
# 4  Afghanistan           2

# %%
religion_filtered = religion_filtered.rename(columns={
    "cname": "country",
    "biu_offrel": "state-sponsored religion index"
})

# %%
religion_filtered2 = religion_filtered.drop_duplicates(
    subset=["country"]
)

religion_filtered2.head()
# Out:
#         country  state-sponsored religion index
# 0   Afghanistan                               2
# 23      Albania                               0
# 48      Algeria                               2
# 73      Andorra                               0
# 98       Angola                               0

# %%
majority_data = pd.read_csv("../data/religious_data.csv")
majority_data.head()
# Out:
#          Region           Country  Year  Diversity_rank  RDI_score  \
# 0         World         All World  2010             NaN   8.982457
# 1         World         All World  2020             NaN   8.966722
# 2  Asia-Pacific  All Asia-Pacific  2010             NaN   8.804169
# 3  Asia-Pacific  All Asia-Pacific  2020             NaN   8.738061
# 4        Europe        All Europe  2010             NaN   4.724689
#
#   Diveristy_level  Buddhists  Christians     Hindus      Jews    Muslims  \
# 0       Very high   4.882030   30.584753  14.977995  0.198187  23.869791
# 1       Very high   4.111001   28.771444  14.936468  0.187421  25.648489
# 2       Very high   8.146677    6.138703  25.278584  0.004395  24.763258
# 3       Very high   6.955449    5.915316  25.671322  0.004072  26.132376
# 4        Moderate   0.271246   74.643921   0.222803  0.187239   5.295826
#
#    Other_Religions  Religiously_Unaffiliated  Level  Countrycode
# 0         2.195080                 23.292166      3          900
# 1         2.183286                 24.161890      3          900
# 2         2.649087                 33.019299      2        90001
# 3         2.476142                 32.845325      2        90001
# 4         0.673520                 18.705446      2        90002

# %%
majority_data2 = majority_data[majority_data["Year"] == 2020]
majority_data2 = majority_data2.rename(columns={
    "Country": "country"
})
majority_data3 = majority_data2.iloc[7:].copy()

majority_data3.head()
# Out:
#                       Region      country  Year  Diversity_rank  RDI_score  \
# 15              Asia-Pacific  Afghanistan  2020           200.0   0.032175
# 17                    Europe      Albania  2020            61.0   4.751494
# 19  Middle East-North Africa      Algeria  2020           182.0   0.372425
# 21        Sub-Saharan Africa       Angola  2020           143.0   1.522381
# 23   Latin America-Caribbean    Argentina  2020           118.0   2.436827
#
#    Diveristy_level  Buddhists  Christians    Hindus      Jews    Muslims  \
# 15        Very low   0.020001    0.019379  0.000128  0.000026  99.861969
# 17        Moderate   0.000158   17.815659  0.000708  0.010050  74.507225
# 19        Very low   0.015001    0.294990  0.000000  0.000130  98.382347
# 21             Low   0.002393   93.044708  0.009274  0.001197   0.255656
# 23        Moderate   0.031062   88.453941  0.002574  0.384978   0.929196
#
#     Other_Religions  Religiously_Unaffiliated  Level  Countrycode
# 15         0.090043                  0.008457      1            4
# 17         0.013316                  7.652888      1            8
# 19         0.041329                  1.266207      1           12
# 21         0.571968                  6.114808      1           24
# 23         0.965338                  9.232909      1           32

# %%
religion_cols = [
    "Buddhists",
    "Christians",
    "Hindus",
    "Jews",
    "Muslims",
    "Other_Religions",
    "Religiously_Unaffiliated"
]

majority_data3["majority_religion"] = majority_data3[religion_cols].idxmax(axis=1)

# %%
# year is 2020 for data

majority_filtered = majority_data3[[
    "Region",
    "country",
    "Diversity_rank",
    "RDI_score",
    "Diveristy_level",
    "Buddhists",
    "Christians",
    "Hindus",
    "Jews",
    "Muslims",
    "Other_Religions",
    "Religiously_Unaffiliated",
    "majority_religion"
]]

# %%
#to merge data together
final_data = violence_filtered.merge(
    religion_filtered2,
    on = ["country"],
    how = "left"
)
final_data.head()
# Out:
#        country  year  intrastate_deaths  civilian_deaths  \
# 0  Afghanistan  1989               5174              303
# 1  Afghanistan  1990               1478              101
# 2  Afghanistan  1991               3302               38
# 3  Afghanistan  1992               4287             1687
# 4  Afghanistan  1993               4071              611
#
#    state-sponsored religion index
# 0                             2.0
# 1                             2.0
# 2                             2.0
# 3                             2.0
# 4                             2.0

# %%
final_data2 = final_data.merge(
    majority_filtered,
    on = ["country"],
    how = "left"
)
final_data2.head()
# Out:
#        country  year  intrastate_deaths  civilian_deaths  \
# 0  Afghanistan  1989               5174              303
# 1  Afghanistan  1990               1478              101
# 2  Afghanistan  1991               3302               38
# 3  Afghanistan  1992               4287             1687
# 4  Afghanistan  1993               4071              611
#
#    state-sponsored religion index        Region  Diversity_rank  RDI_score  \
# 0                             2.0  Asia-Pacific           200.0   0.032175
# 1                             2.0  Asia-Pacific           200.0   0.032175
# 2                             2.0  Asia-Pacific           200.0   0.032175
# 3                             2.0  Asia-Pacific           200.0   0.032175
# 4                             2.0  Asia-Pacific           200.0   0.032175
#
#   Diveristy_level  Buddhists  Christians    Hindus      Jews    Muslims  \
# 0        Very low   0.020001    0.019379  0.000128  0.000026  99.861969
# 1        Very low   0.020001    0.019379  0.000128  0.000026  99.861969
# 2        Very low   0.020001    0.019379  0.000128  0.000026  99.861969
# 3        Very low   0.020001    0.019379  0.000128  0.000026  99.861969
# 4        Very low   0.020001    0.019379  0.000128  0.000026  99.861969
#
#    Other_Religions  Religiously_Unaffiliated majority_religion
# 0         0.090043                  0.008457           Muslims
# 1         0.090043                  0.008457           Muslims
# 2         0.090043                  0.008457           Muslims
# 3         0.090043                  0.008457           Muslims
# 4         0.090043                  0.008457           Muslims

# %%
final_data2.to_csv("../data/final.csv", index=False)
